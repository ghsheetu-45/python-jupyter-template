# %%
# Importing necessary libraries
import matplotlib.pyplot as plt
import numpy as np

# %%
# Generating x values
x = np.linspace(0, 10, 100)
# Calculating y values as the square of x
y = x**2

# %%
# Creating the line plot
plt.figure(figsize=(8, 6))
plt.plot(x, y, label='y = x^2', color='blue')

# %%
# Customizing the line plot
plt.title('Line Plot of y = x^2', fontsize=14)
plt.xlabel('x values', fontsize=12)
plt.ylabel('y values', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
# Out:
# /tmp/ipykernel_10557/3275672431.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# Displaying the line plot
plt.show()

# %%
# Data for the bar plot
categories = ['A', 'B', 'C', 'D']
values = [5, 7, 3, 9]
colors = ['red', 'green', 'blue', 'purple']

# %%
# Creating the bar plot
plt.figure(figsize=(8, 6))
plt.bar(categories, values, color=colors)
# Out:
# <BarContainer object of 4 artists>

# %%
# Customizing the bar plot
plt.title('Bar Plot of Categories', fontsize=14)
plt.xlabel('Categories', fontsize=12)
plt.ylabel('Values', fontsize=12)
# Out:
# Text(0, 0.5, 'Values')

# %%
# Displaying the bar plot
plt.show()
